# %%
import pandas as pd

# Load the new analytics table
df = pd.read_parquet(r'C:\Users\nawaf\OneDrive\Documents\SDAIA_Week2\W2_data_Work\data\processed\analytics_table.parquet')

# Define columns to check
cols = ['user_id', 'country', 'month', 'amount', 'amount_winsor']

# Add outlier column if it exists
if 'amount__is_outlier' in df.columns:
    cols.append('amount__is_outlier')

# Print results
#print("Columns:", df.columns.tolist())
print(df.head())

#df.head()
# Out:
#   order_id user_id  amount  quantity                created_at  status  \
# 0    A0001    0001    12.5         1 2025-12-01 10:05:00+00:00    Paid
# 1    A0002    0002     8.0         2 2025-12-01 11:10:00+00:00    paid
# 2    A0003    0003    <NA>         1 2025-12-02 09:00:00+00:00  Refund
# 3    A0004    0001    25.0      <NA> 2025-12-03 14:30:00+00:00    PAID
# 4    A0005    0004   100.0         1                       NaT    paid
#
#   status_clean  amount_isna  quantity_isna        date    year  month  \
# 0         paid        False          False  2025-12-01  2025.0   12.0
# 1         paid        False          False  2025-12-01  2025.0   12.0
# 2       refund         True          False  2025-12-02  2025.0   12.0
# 3         paid        False           True  2025-12-03  2025.0   12.0
# 4         paid        False          False        None     NaN    NaN
#
#          dow  hour country signup_date  amount_winsor  amount__is_outlier
# ...
